# %% [markdown]
# <a href="https://colab.research.google.com/github/icey6Lulu/InteractiveDataBase/blob/main/RefineInteractive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import
# The [tools library](https://github.com/iceysiyiai/Interactive_Visualization_Tool_Summer2022/blob/main/tools.py) and [vissearch library](https://github.com/iceysiyiai/VisualFeatureSearch/tree/88af6df4ab4378ed8f1f145d31b2b085085c1bcd) are both included in the repo. The other libraries might require installation if environment doesn't already include them.

# %%
import tools
import pandas as pd
import sys, os
sys.path.append('./VisualFeatureSearch')
from vissearch import widgets, util, data
import numpy as np
import torch.nn as nn
import matplotlib
import matplotlib.pyplot as plt
import torch
from torchvision import transforms, utils

# %% [markdown]
# ## Generates Random Picture
# The next cell generates random picture from the [val_250 file](https://github.com/iceysiyiai/Interactive_Visualization_Tool_Summer2022/tree/main/val_250/val_250), along with its image path, label, and original classification.

# %%
image, label = tools.load_random_image()
# print(image)
lable_name = pd.read_csv('val_250/lables.txt', sep = ':')
class_names = []
for i in range(1000):
    class_names.append(lable_name.iloc[i-1, 1].rstrip(","))

print('Image classification: {}'.format(class_names[label]))
#print('Image label:{}'.format(label))
# Out:
# Random number generated: 247
# Image path: ILSVRC2012_val_00000248.JPEG
# Image label:179
# Image classification:  'Staffordshire bullterrier, Staffordshire bull terrier'

# %% [markdown]
# ## Instructions on highlighting
# After running this cell, user may use their mouse to highlight regions on the picture generated. DO NOT proceed to running the next cell until after highlighting.

# %%
convert_tensor = transforms.ToTensor()

size = (224, 224)
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

transform = transforms.Compose([
    transforms.Resize(size),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std) # (x - mean) / std
])

query_vis_transform = transforms.Compose([
    transforms.CenterCrop((256,256)),
    transforms.Resize((224,224))
])

query_model_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

query_img = query_vis_transform(image)
# convert images to Data URLs so we can pass them into the HTML widget
query_img_url = util.image_to_durl(query_img)


highlight_data = None
highlight_index = None
def highlight_callback(data):
    global highlight_data
    highlight_data = data 
util.create_callback('highlight_callback', highlight_callback)

widgets.HighlightWidget(query_img_url, callback_name='highlight_callback')
# Out:
# <script>
#     function isCallbackSupported() {
#         return (typeof Jupyter !== 'undefined') || (typeof google !== 'undefined');
#     }
#
#     function executeCallback(function_name, data) {
#         if (typeof Jupyter !== 'undefined') {
#             let call_statement = function_name + '("' + data + '")';
#             Jupyter.notebook.kernel.execute(call_statement);
#         } else if (typeof google !== 'undefined') {
#             google.colab.kernel.invokeFunction(function_name, [data], {});
#         }
#     }
# </script>
#
# <p>
# <div class="container" style="width: 224px; height: 224px;">
#     <div class="image" style="background-image: url('......'); width: 224px; height: 224px;"></div>
#     <canvas
#         id="drawCanvas_594445531"
#         class="overlay"
#         style="z-index: 10; width: 224px; height: 224px;"
#     ></canvas>
# </div>
# <svg  width="30" height="200">
#         <rect
#           y = "0"
#           id="barplot"
#           width="30"
#           height="200"
#           style="fill: green; stroke-width: 2; stroke: rgb(0, 0, 0)"
#         />
#       </svg>
# </p>
#
# <br>
# <button id="resetBtn_594445531">Reset</button>
#
# <style>
#     .container {
#         position: relative;
#         display: inline-block;
#     }
#
#     .image, .overlay {
#         position: absolute;
#         left: 0px;
#         top: 0px;
#     }
#
#     .overlay {
#         opacity: 0.5;
#         transition: opacity .1s ease-in-out;
#     }
#
#     .overlay:hover {
#         opacity: 0.7;
#     }
# </style>
#
# <script>
# (function() {
#     let resetBtn = document.getElementById('resetBtn_594445531');
#     let drawCanvas = document.getElementById('drawCanvas_594445531');
#
#     drawCanvas.width = 224;
#     drawCanvas.height = 224;
#     let ctx = drawCanvas.getContext('2d');
#
#     let drawing = false;
#
#     function mouseDown() {
#         drawing = true;
#     }
#
#     async function mouseUp() {
#         drawing = false;
#         if('highlight_callback' !== 'None') {
#             executeCallback('highlight_callback', drawCanvas.toDataURL());
#             let num = 50;
#             await fetch('out.txt')
#                 .then(response => response.text())
#                 .then(text => {
#                     num = parseFloat(text);
#                 });
#             console.log(num);
#             document.getElementById('barplot').setAttribute("height", 200*num);
#         }
#     }
#
#     function processData(allText) {
#         alert(allText);
#
#
#         return allText;
#     }
#
#     function handleMove(e) {
#         if(!drawing) return;
#         ctx.fillStyle = '#fff';
#         ctx.beginPath();
#         ctx.arc(e.offsetX, e.offsetY, 20, 0, 2 * Math.PI);
#         ctx.fill();
#     }
#
#     function reset() {
#         ctx.clearRect(0, 0, 224, 224);
#         document.getElementById('barplot').setAttribute("height", 200);
#         if('highlight_callback' !== 'None') {
#             executeCallback('highlight_callback', drawCanvas.toDataURL());
#         }
#     }
#
#     drawCanvas.onmousedown = mouseDown;
#     drawCanvas.onmouseup = mouseUp;
#     drawCanvas.onmousemove = handleMove;
#
#     resetBtn.onclick = reset;
# })();
#
#
# </script>

# %% [markdown]
# ## Instruction on changing the type of occlusion
# On the last line of code
#     `tools.score_gen_csv(tools.transform_Noise, img_input, mask_input, model)`
# user may change `tools.transform_Noise` into one of the four options below to alternate between the four types of occlusions encoded.
# * `tools.transform_deletion`
# * `tools.transform_preservation`
# * `tools.transform_Gaussian`
# * `tools.transform_Noise`

# %%
mask = util.durl_to_image(highlight_data)
mask_arr = np.asarray(mask)[:,:,3] / 256 # take just the alpha channel

model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', weights=True)
model.eval()

img_input = tools.img_transform(query_img)
mask_input = tools.mask_transform(mask_arr)
print('Original image classification: {}'.format(class_names[label]))
tools.score_gen_csv(tools.transform_Noise, img_input, mask_input, model)
# Out:
# Using cache found in /Users/iceyai/.cache/torch/hub/pytorch_vision_v0.10.0
# /Users/iceyai/opt/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Original image classification:  'Staffordshire bullterrier, Staffordshire bull terrier'
# Class #1 -  'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier' - Logit: 13.42 - Softmax: 70.06%
# Class #2 -  'Staffordshire bullterrier, Staffordshire bull terrier' - Logit: 12.33 - Softmax: 23.56%
# Class #3 -  'kelpie' - Logit: 9.77 - Softmax: 1.82%
# Class #4 -  'Chesapeake Bay retriever' - Logit: 9.49 - Softmax: 1.38%
# Class #5 -  'Mexican hairless' - Logit: 9.22 - Softmax: 1.05%
# /Users/iceyai/Documents/Princeton/OURSIP/Interactive_Visualization_Tool_Summer2022/tools.py:150: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_softmax = softmax(y_output)
